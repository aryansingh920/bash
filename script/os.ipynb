# %%
import os
import shutil
import pathlib

# %%
os.getcwd()
# Out:
# '/Users/aryansingh/Documents/bash/script'

# %%
os.listdir()
# Out:
# ['rate_limiting.py',
#  'suspicious_log.py',
#  'logs',
#  'practice.ipynb',
#  'log_parsing.py']

# %%
os.path.exists("logs")
# Out:
# True

# %%
os.mkdir("logs2")

# %%
os.rmdir("logs2")

# %%
os.makedirs('data/2026/march', exist_ok=True)
# recursive file path

# %%
shutil.rmtree("data")

# %%
base_path = os.getcwd()
fileName = "config.json"
fullPath = os.path.join(base_path,"../",fileName)
normPath = os.path.normpath(fullPath)

# %%
def touch(path):
    if not os.path.exists(path):
        with open(path,'a'):
            os.utime(path,None)
    else:
        os.utime(path,None)


# touch(os.path.normpath(fullPath))

# %%
pathlib.Path(os.path.normpath(fullPath)).touch()

# %%
os.path.dirname(os.path.normpath(fullPath))
# Out:
# '/Users/aryansingh/Documents/bash'

# %%
os.path.basename(os.path.normpath(fullPath))
# Out:
# 'config.json'

# %%
os.path.splitext(os.path.normpath(fullPath))
# Out:
# ('/Users/aryansingh/Documents/bash/config', '.json')

# %%
os.path.isfile(os.path.normpath(fullPath))
# Out:
# True

# %%
os.path.isdir(os.getcwd())
# Out:
# True

# %%
os.environ["APP_SECRET"] = "production"

# %%
os.environ.get("APP_SECRET")
# Out:
# 'production'

# %%
os.getpid()
# Out:
# 59609

# %%
os.getppid()
# Out:
# 56824

# %%
dir = os.path.normpath(os.path.join(os.getcwd(),"../"))
for root,dirs,files in os.walk(dir):
    print(root," : ",dirs," : ",files)

# %%
filePath = os.path.normpath(os.path.join(os.getcwd(),"../","config2.json"))
os.rename(filePath,os.path.join(os.path.dirname(filePath),"config.json"))

# %%
filePath
# Out:
# '/Users/aryansingh/Documents/bash/config.json'

# %%
os.remove(os.path.normpath(os.path.join(os.getcwd(),"../","config.json")))

# %%
os.stat(os.path.join(os.getcwd(),"rate_limiting.py")).st_size/1024
# Out:
# 2.17578125
